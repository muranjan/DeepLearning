# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)

# %%
#!ls /content/drive/My\ Drive/ComputerVisionHackathon/
base_dir = '/content/drive/My Drive/ComputerVisionHackathon/' 
#!ls /content/drive/My\ Drive/ComputerVisionHackathon/train.csv

# %%
train = pd.read_csv(base_dir+"train.csv")
train.head()

# %%
emergency_train = train[train.emergency_or_not == 1]
non_emergency_train = train[train.emergency_or_not == 0]

# %%
print(emergency_train.shape)
print(non_emergency_train.shape)

emergency_train_names = emergency_train['image_names'].tolist()
non_emergency_train_names = non_emergency_train['image_names'].tolist()


print(len(emergency_train_names))
print(len(non_emergency_train_names))
print(emergency_train_names)

print(non_emergency_train_names)

# %%
base_dir = '/content/drive/My\ Drive/ComputerVisionHackathon/' 
emer = base_dir + "emer"
nonemer = base_dir + "nonemer"
print(emer, nonemer)


# !mkdir $emer
# !mkdir $nonemer
# !ls -al $base_dir

emer = emer + "/"
nonemer = nonemer + "/"
print (emer)

# %%
for count,item in enumerate(emergency_train_names):
    item = base_dir+'images/'+str(item)
    print (count, item)
    ! mv $item $emer

print("Pythong ends here")

# %%
# %%time
for count, item in enumerate(non_emergency_train_names):
    item = base_dir+'images/'+str(item)
    print (count, item)
    ! mv $item $nonemer

print("Pythong ends here")

# %%
base_dir = '/content/drive/My Drive/ComputerVisionHackathon/' 
test = pd.read_csv(base_dir+"test.csv")
test.head()

# %%
test_image_names = test['image_names'].tolist()
print(len(test_image_names))

# %%
# %%time
base_dir = '/content/drive/My\ Drive/ComputerVisionHackathon/' 
test_dir = base_dir+"/data/test/"
for count, item in enumerate(test_image_names):
    item = base_dir+'images/'+str(item)
    print (count, item)
    ! mv $item $test_dir

print("Pythong ends here")

# %%
images = base_dir+'images/'
# !ls $images

# %% [markdown]
# # Data Exploration and Model Building

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
TRAIN_DIR = '/content/drive/My Drive/ComputerVisionHackathon/data/train'

datagen = ImageDataGenerator(validation_split=0.2, rescale=1./255)

train_generator = datagen.flow_from_directory(
    TRAIN_DIR, 
    subset='training'
)

val_generator = datagen.flow_from_directory(
    TRAIN_DIR,
    subset='validation'
)
