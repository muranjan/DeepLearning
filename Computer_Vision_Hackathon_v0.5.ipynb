# %%
## This notebook has been created for Analytics Vidhya hackathon for Computer Vision:
##  https://datahack.analyticsvidhya.com/contest/janatahack-computer-vision-hackathon/#LeaderBoard
## Binary Classification (Emergency and Non Emergency dataset)


import sys
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.utils import to_categorical
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten, Dropout
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# %pylab inline

# Time Keeper
import timeit
start = timeit.default_timer()

# Just to check If GPU is available.
tf.test.gpu_device_name()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# '/device:GPU:0'

# %%
# This cell will keep all the PATHS used.

DATA_DIR = '/content/sample_data/data/'

TRAIN_DIR = '/content/sample_data/data/train/'

TRAIN_EMERGENCY = '/content/sample_data/data/train/1_emergency/'

TRAIN_NON_EMERGENCY = '/content/sample_data/data/train/0_nonemergency/'

TEST_PATH = '/content/sample_data/data/test_root/test/'

# %%
# Data Exploratioon => To check if all the images are of same sizes.

import os
from PIL import Image 

folder_images = "/content/sample_data/data/train/emer/_TO_STOP_THIS_CELL"
size_images = dict()

for dirpath, _, filenames in os.walk(folder_images):
    print("How many execute")
    for path_image in filenames:
        image = os.path.abspath(os.path.join(dirpath, path_image))
        with Image.open(image) as img:
            width, heigth = img.size
            size_images[path_image] = {'width': width, 'heigth': heigth}
            if width != 224 or heigth != 224:
              print(width,heigth,path_image)
            else:
              sys.stdout.write('-')

#print(size_images)

# %%
# define CNN model

def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(224, 224, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.25))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.3))
	model.add(Dense(64, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.22))
	model.add(Dense(32, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.25))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	#opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
	return model

# %%
# plot diagnostic learning curves

def summarize_diagnostics(history):
	# plot loss
	pyplot.subplot(211)
	pyplot.title('Cross Entropy Loss')
	pyplot.plot(history.history['loss'], color='blue', label='train')
	pyplot.plot(history.history['val_loss'], color='orange', label='test')
	# plot accuracy
	pyplot.subplot(212)
	pyplot.title('Classification Accuracy')
	pyplot.plot(history.history['accuracy'], color='blue', label='train')
	pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
	# save plot to file
	filename = sys.argv[0].split('/')[-1]
	pyplot.savefig(filename + '_plot.png')
	pyplot.show()
 
	# Lets save the csv file for later analysis.
	new_dict = history.history
	df = pd.DataFrame(new_dict)
	df.to_csv("epoch_trends.csv", index=False) # write to csv

# %%
# run the model pipeline for evaluating a model. Use Image Augmentation for normalizing images.
def model_pipeline():
  # define model
  model = define_model()
  
  # create data generators
  
  datagen = ImageDataGenerator(validation_split=0.2,
                               rescale=1.0/255.0, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1,
                               horizontal_flip=True
                               )
  
  train_generator = datagen.flow_from_directory(
                              TRAIN_DIR, 
                              subset='training',
                              color_mode="rgb", 
                              class_mode='binary',
                              shuffle=True,
                              batch_size=32,
                              target_size=(224, 224),
                              seed=123
    )
  
  # Its always good idea to print and check labels of train class
  labels = (train_generator.class_indices)
  print(labels)

  val_generator = datagen.flow_from_directory(
                              TRAIN_DIR,
                              subset='validation',
                              color_mode="rgb", 
                              class_mode='binary',
                              shuffle=True,
                              batch_size=32,
                              target_size=(224, 224),
                              seed=123
    )

  # Fit model
  history = model.fit_generator(train_generator, 
                                steps_per_epoch=len(train_generator),
                                validation_data=val_generator, 
                                validation_steps=len(val_generator), 
                                epochs=200, # Lets test Epoch from 50 to 500
                                verbose=2
                                )
  # Lets save the model as Hierarchical Data Format ( H5 )
  model.save('final_model.h5')
  
  # Plotting learning curves
  summarize_diagnostics(history)

# entry point, run the test harness
model_pipeline()
# Out:
# Found 1318 images belonging to 2 classes.
# {'0_nonemergency': 0, '1_emergency': 1}
# Found 328 images belonging to 2 classes.
# Epoch 1/200
#  - 20s - loss: 1.2133 - accuracy: 0.5857 - val_loss: 0.6448 - val_accuracy: 0.6189
# Epoch 2/200
#  - 20s - loss: 0.6269 - accuracy: 0.6753 - val_loss: 0.6338 - val_accuracy: 0.7012
# Epoch 3/200
#  - 19s - loss: 0.5943 - accuracy: 0.7223 - val_loss: 0.8286 - val_accuracy: 0.7500
# Epoch 4/200
#  - 20s - loss: 0.5907 - accuracy: 0.7155 - val_loss: 0.4328 - val_accuracy: 0.7165
# Epoch 5/200
#  - 19s - loss: 0.5645 - accuracy: 0.7223 - val_loss: 0.4649 - val_accuracy: 0.7134
# Epoch 6/200
#  - 20s - loss: 0.5427 - accuracy: 0.7564 - val_loss: 0.3776 - val_accuracy: 0.7866
# Epoch 7/200
#  - 20s - loss: 0.5064 - accuracy: 0.7701 - val_loss: 0.3849 - val_accuracy: 0.8049
# Epoch 8/200
#  - 19s - loss: 0.5216 - accuracy: 0.7564 - val_loss: 0.4382 - val_accuracy: 0.7927
# Epoch 9/200
#  - 20s - loss: 0.4761 - accuracy: 0.7769 - val_loss: 0.3847 - val_accuracy: 0.7774
# Epoch 10/200
#  - 19s - loss: 0.4740 - accuracy: 0.7807 - val_loss: 0.6305 - val_accuracy: 0.7622
# Epoch 11/200
#  - 20s - loss: 0.4655 - accuracy: 0.8012 - val_loss: 0.1929 - val_accuracy: 0.8140
# Epoch 12/200
#  - 20s - loss: 0.4563 - accuracy: 0.8050 - val_loss: 0.2780 - val_accuracy: 0.7866
# Epoch 13/200
#  - 20s - loss: 0.4358 - accuracy: 0.8217 - val_loss: 0.3504 - val_accuracy: 0.7835
# Epoch 14/200
#  - 20s - loss: 0.4549 - accuracy: 0.8103 - val_loss: 0.3425 - val_accuracy: 0.7774
# Epoch 15/200
#  - 19s - loss: 0.4350 - accuracy: 0.8156 - val_loss: 0.3910 - val_accuracy: 0.7896
# Epoch 16/200
#  - 20s - loss: 0.3963 - accuracy: 0.8278 - val_loss: 0.1639 - val_accuracy: 0.8232
# Epoch 17/200
#  - 19s - loss: 0.3995 - accuracy: 0.8323 - val_loss: 0.3387 - val_accuracy: 0.8110
# Epoch 18/200
#  - 20s - loss: 0.3874 - accuracy: 0.8300 - val_loss: 0.1680 - val_accuracy: 0.8476
# Epoch 19/200
#  - 20s - loss: 0.3803 - accuracy: 0.8316 - val_loss: 0.3715 - val_accuracy: 0.8110
# Epoch 20/200
#  - 20s - loss: 0.3807 - accuracy: 0.8490 - val_loss: 0.4441 - val_accuracy: 0.7988
# Epoch 21/200
#  - 20s - loss: 0.3869 - accuracy: 0.8263 - val_loss: 0.6261 - val_accuracy: 0.8293
# Epoch 22/200
#  - 19s - loss: 0.3994 - accuracy: 0.8247 - val_loss: 0.6987 - val_accuracy: 0.8323
# Epoch 23/200
#  - 19s - loss: 0.3499 - accuracy: 0.8551 - val_loss: 0.3724 - val_accuracy: 0.8476
# Epoch 24/200
#  - 19s - loss: 0.3674 - accuracy: 0.8376 - val_loss: 0.4733 - val_accuracy: 0.8201
# Epoch 25/200
#  - 19s - loss: 0.3409 - accuracy: 0.8619 - val_loss: 0.5233 - val_accuracy: 0.8628
# Epoch 26/200
#  - 19s - loss: 0.3584 - accuracy: 0.8543 - val_loss: 0.5427 - val_accuracy: 0.8476
# Epoch 27/200
#  - 19s - loss: 0.3372 - accuracy: 0.8703 - val_loss: 0.4547 - val_accuracy: 0.8232
# Epoch 28/200
#  - 20s - loss: 0.3425 - accuracy: 0.8551 - val_loss: 0.2564 - val_accuracy: 0.8140
# Epoch 29/200
#  - 20s - loss: 0.3381 - accuracy: 0.8543 - val_loss: 0.5932 - val_accuracy: 0.8780
# Epoch 30/200
#  - 19s - loss: 0.3526 - accuracy: 0.8483 - val_loss: 0.4216 - val_accuracy: 0.8537
# Epoch 31/200
#  - 20s - loss: 0.3329 - accuracy: 0.8596 - val_loss: 0.3553 - val_accuracy: 0.8445
# Epoch 32/200
#  - 20s - loss: 0.3095 - accuracy: 0.8687 - val_loss: 0.4970 - val_accuracy: 0.8780
# Epoch 33/200
#  - 20s - loss: 0.3220 - accuracy: 0.8725 - val_loss: 0.5633 - val_accuracy: 0.8537
# Epoch 34/200
#  - 20s - loss: 0.3091 - accuracy: 0.8703 - val_loss: 0.1658 - val_accuracy: 0.8567
# Epoch 35/200
#  - 20s - loss: 0.2826 - accuracy: 0.8862 - val_loss: 0.1776 - val_accuracy: 0.8689
# Epoch 36/200
#  - 20s - loss: 0.2904 - accuracy: 0.8778 - val_loss: 0.3894 - val_accuracy: 0.8079
# Epoch 37/200
#  - 20s - loss: 0.2713 - accuracy: 0.8862 - val_loss: 0.0947 - val_accuracy: 0.8476
# Epoch 38/200
#  - 20s - loss: 0.2863 - accuracy: 0.8771 - val_loss: 0.7817 - val_accuracy: 0.8720
# Epoch 39/200
#  - 19s - loss: 0.2829 - accuracy: 0.8862 - val_loss: 0.2016 - val_accuracy: 0.8689
# Epoch 40/200
#  - 19s - loss: 0.2631 - accuracy: 0.8991 - val_loss: 0.7627 - val_accuracy: 0.9055
# Epoch 41/200
#  - 19s - loss: 0.2512 - accuracy: 0.9014 - val_loss: 0.7996 - val_accuracy: 0.8384
# Epoch 42/200
#  - 20s - loss: 0.2634 - accuracy: 0.8938 - val_loss: 0.1879 - val_accuracy: 0.8841
# Epoch 43/200
#  - 20s - loss: 0.2332 - accuracy: 0.9052 - val_loss: 0.3400 - val_accuracy: 0.8872
# Epoch 44/200
#  - 20s - loss: 0.2529 - accuracy: 0.8938 - val_loss: 0.1996 - val_accuracy: 0.8811
# Epoch 45/200
#  - 20s - loss: 0.2624 - accuracy: 0.8907 - val_loss: 0.2326 - val_accuracy: 0.8811
# Epoch 46/200
#  - 20s - loss: 0.2255 - accuracy: 0.9211 - val_loss: 0.5302 - val_accuracy: 0.8841
# Epoch 47/200
#  - 19s - loss: 0.2398 - accuracy: 0.9074 - val_loss: 0.2973 - val_accuracy: 0.8933
# Epoch 48/200
#  - 20s - loss: 0.2369 - accuracy: 0.9036 - val_loss: 0.6877 - val_accuracy: 0.8720
# Epoch 49/200
#  - 20s - loss: 0.1949 - accuracy: 0.9211 - val_loss: 0.1860 - val_accuracy: 0.8628
# Epoch 50/200
#  - 20s - loss: 0.2074 - accuracy: 0.9158 - val_loss: 0.4597 - val_accuracy: 0.8933
# Epoch 51/200
#  - 20s - loss: 0.2203 - accuracy: 0.9090 - val_loss: 0.1370 - val_accuracy: 0.8720
# Epoch 52/200
#  - 20s - loss: 0.1950 - accuracy: 0.9211 - val_loss: 0.3318 - val_accuracy: 0.8689
# Epoch 53/200
#  - 20s - loss: 0.2357 - accuracy: 0.9082 - val_loss: 0.4583 - val_accuracy: 0.8628
# Epoch 54/200
#  - 19s - loss: 0.2314 - accuracy: 0.9082 - val_loss: 0.2110 - val_accuracy: 0.8872
# Epoch 55/200
#  - 19s - loss: 0.2135 - accuracy: 0.9219 - val_loss: 0.1154 - val_accuracy: 0.8841
# Epoch 56/200
#  - 18s - loss: 0.2117 - accuracy: 0.9211 - val_loss: 0.1032 - val_accuracy: 0.8841
# Epoch 57/200
#  - 19s - loss: 0.2111 - accuracy: 0.9127 - val_loss: 0.8869 - val_accuracy: 0.8841
# Epoch 58/200
#  - 19s - loss: 0.1943 - accuracy: 0.9158 - val_loss: 0.0495 - val_accuracy: 0.9024
# Epoch 59/200
#  - 19s - loss: 0.1972 - accuracy: 0.9294 - val_loss: 0.0694 - val_accuracy: 0.8902
# Epoch 60/200
#  - 19s - loss: 0.2013 - accuracy: 0.9143 - val_loss: 0.2899 - val_accuracy: 0.8445
# Epoch 61/200
#  - 19s - loss: 0.1957 - accuracy: 0.9287 - val_loss: 0.0643 - val_accuracy: 0.8902
# Epoch 62/200
#  - 20s - loss: 0.2021 - accuracy: 0.9256 - val_loss: 0.4236 - val_accuracy: 0.7561
# Epoch 63/200
#  - 20s - loss: 0.3721 - accuracy: 0.8498 - val_loss: 0.2048 - val_accuracy: 0.8537
# Epoch 64/200
#  - 20s - loss: 0.2486 - accuracy: 0.9014 - val_loss: 0.0261 - val_accuracy: 0.9055
# Epoch 65/200
#  - 20s - loss: 0.2044 - accuracy: 0.9150 - val_loss: 0.2438 - val_accuracy: 0.8994
# Epoch 66/200
#  - 20s - loss: 0.1739 - accuracy: 0.9355 - val_loss: 0.6502 - val_accuracy: 0.8841
# Epoch 67/200
#  - 20s - loss: 0.1660 - accuracy: 0.9332 - val_loss: 0.5435 - val_accuracy: 0.8933
# Epoch 68/200
#  - 20s - loss: 0.2097 - accuracy: 0.9188 - val_loss: 0.3385 - val_accuracy: 0.8841
# Epoch 69/200
#  - 20s - loss: 0.1664 - accuracy: 0.9332 - val_loss: 0.0431 - val_accuracy: 0.8994
# Epoch 70/200
#  - 20s - loss: 0.1656 - accuracy: 0.9294 - val_loss: 0.0493 - val_accuracy: 0.8963
# Epoch 71/200
#  - 20s - loss: 0.1616 - accuracy: 0.9287 - val_loss: 0.0800 - val_accuracy: 0.8933
# Epoch 72/200
#  - 19s - loss: 0.1606 - accuracy: 0.9370 - val_loss: 0.0372 - val_accuracy: 0.8841
# Epoch 73/200
#  - 20s - loss: 0.1521 - accuracy: 0.9454 - val_loss: 0.9464 - val_accuracy: 0.8780
# Epoch 74/200
#  - 19s - loss: 0.1576 - accuracy: 0.9370 - val_loss: 0.2751 - val_accuracy: 0.8567
# Epoch 75/200
#  - 20s - loss: 0.1582 - accuracy: 0.9355 - val_loss: 0.4469 - val_accuracy: 0.8963
# Epoch 76/200
#  - 20s - loss: 0.1440 - accuracy: 0.9499 - val_loss: 0.0395 - val_accuracy: 0.8598
# Epoch 77/200
#  - 20s - loss: 0.1616 - accuracy: 0.9370 - val_loss: 0.6693 - val_accuracy: 0.8933
# Epoch 78/200
#  - 20s - loss: 0.1422 - accuracy: 0.9499 - val_loss: 0.0224 - val_accuracy: 0.8902
# Epoch 79/200
#  - 19s - loss: 0.1872 - accuracy: 0.9264 - val_loss: 0.0967 - val_accuracy: 0.8841
# Epoch 80/200
#  - 20s - loss: 0.2179 - accuracy: 0.9196 - val_loss: 0.5644 - val_accuracy: 0.8598
# Epoch 81/200
#  - 19s - loss: 0.1567 - accuracy: 0.9454 - val_loss: 0.1835 - val_accuracy: 0.8933
# Epoch 82/200
#  - 20s - loss: 0.1495 - accuracy: 0.9461 - val_loss: 0.3446 - val_accuracy: 0.8872
# Epoch 83/200
#  - 19s - loss: 0.1475 - accuracy: 0.9431 - val_loss: 0.2968 - val_accuracy: 0.9024
# Epoch 84/200
#  - 20s - loss: 0.1366 - accuracy: 0.9545 - val_loss: 0.1886 - val_accuracy: 0.9085
# Epoch 85/200
#  - 19s - loss: 0.1376 - accuracy: 0.9552 - val_loss: 0.0240 - val_accuracy: 0.9024
# Epoch 86/200
#  - 20s - loss: 0.1707 - accuracy: 0.9302 - val_loss: 0.0196 - val_accuracy: 0.8841
# Epoch 87/200
#  - 19s - loss: 0.1564 - accuracy: 0.9363 - val_loss: 0.0249 - val_accuracy: 0.9024
# Epoch 88/200
#  - 20s - loss: 0.1487 - accuracy: 0.9484 - val_loss: 0.6895 - val_accuracy: 0.8963
# Epoch 89/200
#  - 20s - loss: 0.1368 - accuracy: 0.9461 - val_loss: 0.6712 - val_accuracy: 0.8720
# Epoch 90/200
#  - 20s - loss: 0.1351 - accuracy: 0.9446 - val_loss: 0.2517 - val_accuracy: 0.8872
# Epoch 91/200
#  - 20s - loss: 0.1463 - accuracy: 0.9446 - val_loss: 0.0873 - val_accuracy: 0.9055
# Epoch 92/200
#  - 20s - loss: 0.1239 - accuracy: 0.9583 - val_loss: 0.4923 - val_accuracy: 0.9024
# Epoch 93/200
#  - 20s - loss: 0.1261 - accuracy: 0.9598 - val_loss: 0.1994 - val_accuracy: 0.8841
# Epoch 94/200
#  - 20s - loss: 0.1231 - accuracy: 0.9476 - val_loss: 0.1332 - val_accuracy: 0.8933
# Epoch 95/200
#  - 20s - loss: 0.1024 - accuracy: 0.9621 - val_loss: 1.1145 - val_accuracy: 0.8963
# Epoch 96/200
#  - 20s - loss: 0.1487 - accuracy: 0.9507 - val_loss: 0.2321 - val_accuracy: 0.9055
# Epoch 97/200
#  - 20s - loss: 0.1533 - accuracy: 0.9446 - val_loss: 0.5155 - val_accuracy: 0.8811
# Epoch 98/200
#  - 20s - loss: 0.1222 - accuracy: 0.9552 - val_loss: 0.6127 - val_accuracy: 0.8872
# Epoch 99/200
#  - 20s - loss: 0.1053 - accuracy: 0.9613 - val_loss: 0.1323 - val_accuracy: 0.8933
# Epoch 100/200
#  - 20s - loss: 0.1208 - accuracy: 0.9484 - val_loss: 0.0663 - val_accuracy: 0.8750
# Epoch 101/200
#  - 20s - loss: 0.1172 - accuracy: 0.9537 - val_loss: 0.0121 - val_accuracy: 0.8780
# Epoch 102/200
#  - 20s - loss: 0.1053 - accuracy: 0.9575 - val_loss: 0.2835 - val_accuracy: 0.8933
# Epoch 103/200
#  - 20s - loss: 0.1217 - accuracy: 0.9530 - val_loss: 0.2903 - val_accuracy: 0.8872
# Epoch 104/200
#  - 20s - loss: 0.1262 - accuracy: 0.9484 - val_loss: 0.2044 - val_accuracy: 0.8963
# Epoch 105/200
#  - 20s - loss: 0.1236 - accuracy: 0.9492 - val_loss: 0.4618 - val_accuracy: 0.8994
# Epoch 106/200
#  - 20s - loss: 0.1845 - accuracy: 0.9219 - val_loss: 0.1518 - val_accuracy: 0.8963
# Epoch 107/200
#  - 20s - loss: 0.1244 - accuracy: 0.9560 - val_loss: 0.8229 - val_accuracy: 0.9024
# Epoch 108/200
#  - 20s - loss: 0.1315 - accuracy: 0.9469 - val_loss: 0.1496 - val_accuracy: 0.8689
# Epoch 109/200
#  - 19s - loss: 0.1080 - accuracy: 0.9598 - val_loss: 0.2390 - val_accuracy: 0.8963
# Epoch 110/200
#  - 20s - loss: 0.1059 - accuracy: 0.9666 - val_loss: 0.0833 - val_accuracy: 0.9024
# Epoch 111/200
#  - 19s - loss: 0.1053 - accuracy: 0.9643 - val_loss: 0.1700 - val_accuracy: 0.8963
# Epoch 112/200
#  - 20s - loss: 0.1019 - accuracy: 0.9568 - val_loss: 0.0725 - val_accuracy: 0.8872
# Epoch 113/200
#  - 19s - loss: 0.1013 - accuracy: 0.9560 - val_loss: 0.1296 - val_accuracy: 0.9085
# Epoch 114/200
#  - 20s - loss: 0.1063 - accuracy: 0.9560 - val_loss: 0.1675 - val_accuracy: 0.8841
# Epoch 115/200
#  - 19s - loss: 0.1335 - accuracy: 0.9431 - val_loss: 0.8319 - val_accuracy: 0.8963
# Epoch 116/200
#  - 20s - loss: 0.1431 - accuracy: 0.9522 - val_loss: 0.4249 - val_accuracy: 0.8963
# Epoch 117/200
#  - 19s - loss: 0.1193 - accuracy: 0.9568 - val_loss: 0.0552 - val_accuracy: 0.8841
# Epoch 118/200
#  - 20s - loss: 0.1054 - accuracy: 0.9583 - val_loss: 0.5788 - val_accuracy: 0.8811
# Epoch 119/200
#  - 19s - loss: 0.0974 - accuracy: 0.9613 - val_loss: 0.0166 - val_accuracy: 0.9024
# Epoch 120/200
#  - 20s - loss: 0.1364 - accuracy: 0.9499 - val_loss: 0.0024 - val_accuracy: 0.8933
# Epoch 121/200
#  - 20s - loss: 0.1126 - accuracy: 0.9537 - val_loss: 0.0080 - val_accuracy: 0.8933
# Epoch 122/200
#  - 20s - loss: 0.1138 - accuracy: 0.9552 - val_loss: 0.1146 - val_accuracy: 0.8872
# Epoch 123/200
#  - 20s - loss: 0.0894 - accuracy: 0.9643 - val_loss: 0.9971 - val_accuracy: 0.9177
# Epoch 124/200
#  - 20s - loss: 0.0848 - accuracy: 0.9674 - val_loss: 0.0188 - val_accuracy: 0.8841
# Epoch 125/200
#  - 20s - loss: 0.0673 - accuracy: 0.9750 - val_loss: 0.2368 - val_accuracy: 0.8963
# Epoch 126/200
#  - 19s - loss: 0.1168 - accuracy: 0.9537 - val_loss: 0.6900 - val_accuracy: 0.8750
# Epoch 127/200
#  - 20s - loss: 0.0913 - accuracy: 0.9621 - val_loss: 0.3031 - val_accuracy: 0.8841
# Epoch 128/200
#  - 19s - loss: 0.0854 - accuracy: 0.9681 - val_loss: 0.0430 - val_accuracy: 0.8872
# Epoch 129/200
#  - 20s - loss: 0.1016 - accuracy: 0.9598 - val_loss: 0.1238 - val_accuracy: 0.8994
# Epoch 130/200
#  - 19s - loss: 0.0974 - accuracy: 0.9643 - val_loss: 0.0984 - val_accuracy: 0.8933
# Epoch 131/200
#  - 19s - loss: 0.0797 - accuracy: 0.9666 - val_loss: 2.9750e-04 - val_accuracy: 0.8841
# Epoch 132/200
#  - 19s - loss: 0.0831 - accuracy: 0.9719 - val_loss: 0.0685 - val_accuracy: 0.9116
# Epoch 133/200
#  - 19s - loss: 0.0645 - accuracy: 0.9757 - val_loss: 0.0027 - val_accuracy: 0.9085
# Epoch 134/200
#  - 19s - loss: 0.0830 - accuracy: 0.9659 - val_loss: 0.0071 - val_accuracy: 0.9055
# Epoch 135/200
#  - 19s - loss: 0.0730 - accuracy: 0.9719 - val_loss: 0.0134 - val_accuracy: 0.8994
# Epoch 136/200
#  - 19s - loss: 0.0904 - accuracy: 0.9674 - val_loss: 1.0067 - val_accuracy: 0.8872
# Epoch 137/200
#  - 20s - loss: 0.0763 - accuracy: 0.9704 - val_loss: 0.4438 - val_accuracy: 0.8963
# Epoch 138/200
#  - 20s - loss: 0.0938 - accuracy: 0.9666 - val_loss: 0.9782 - val_accuracy: 0.9177
# Epoch 139/200
#  - 20s - loss: 0.0708 - accuracy: 0.9803 - val_loss: 1.2138 - val_accuracy: 0.9085
# Epoch 140/200
#  - 20s - loss: 0.0815 - accuracy: 0.9674 - val_loss: 0.0052 - val_accuracy: 0.9024
# Epoch 141/200
#  - 20s - loss: 0.0998 - accuracy: 0.9704 - val_loss: 0.5673 - val_accuracy: 0.8963
# Epoch 142/200
#  - 20s - loss: 0.0805 - accuracy: 0.9659 - val_loss: 0.3057 - val_accuracy: 0.9055
# Epoch 143/200
#  - 20s - loss: 0.0851 - accuracy: 0.9697 - val_loss: 0.1013 - val_accuracy: 0.8994
# Epoch 144/200
#  - 20s - loss: 0.0884 - accuracy: 0.9636 - val_loss: 0.2941 - val_accuracy: 0.8902
# Epoch 145/200
#  - 20s - loss: 0.0744 - accuracy: 0.9750 - val_loss: 0.0054 - val_accuracy: 0.8994
# Epoch 146/200
#  - 20s - loss: 0.0739 - accuracy: 0.9712 - val_loss: 0.0872 - val_accuracy: 0.8933
# Epoch 147/200
#  - 20s - loss: 0.0834 - accuracy: 0.9727 - val_loss: 0.9731 - val_accuracy: 0.8659
# Epoch 148/200
#  - 19s - loss: 0.0876 - accuracy: 0.9712 - val_loss: 0.2941 - val_accuracy: 0.9024
# Epoch 149/200
#  - 20s - loss: 0.0971 - accuracy: 0.9681 - val_loss: 0.4897 - val_accuracy: 0.8963
# Epoch 150/200
#  - 19s - loss: 0.0995 - accuracy: 0.9636 - val_loss: 0.0153 - val_accuracy: 0.8780
# Epoch 151/200
#  - 20s - loss: 0.0687 - accuracy: 0.9765 - val_loss: 0.0144 - val_accuracy: 0.9024
# Epoch 152/200
#  - 20s - loss: 0.0734 - accuracy: 0.9757 - val_loss: 0.3512 - val_accuracy: 0.9116
# Epoch 153/200
#  - 20s - loss: 0.0512 - accuracy: 0.9772 - val_loss: 0.0010 - val_accuracy: 0.8872
# Epoch 154/200
#  - 20s - loss: 0.0797 - accuracy: 0.9780 - val_loss: 0.2806 - val_accuracy: 0.9055
# Epoch 155/200
#  - 19s - loss: 0.0743 - accuracy: 0.9689 - val_loss: 0.0469 - val_accuracy: 0.9055
# Epoch 156/200
#  - 20s - loss: 0.0812 - accuracy: 0.9719 - val_loss: 0.0289 - val_accuracy: 0.8841
# Epoch 157/200
#  - 19s - loss: 0.0720 - accuracy: 0.9734 - val_loss: 0.0979 - val_accuracy: 0.8963
# Epoch 158/200
#  - 20s - loss: 0.0638 - accuracy: 0.9742 - val_loss: 0.0120 - val_accuracy: 0.9055
# Epoch 159/200
#  - 19s - loss: 0.0724 - accuracy: 0.9734 - val_loss: 0.3524 - val_accuracy: 0.9207
# Epoch 160/200
#  - 20s - loss: 0.0783 - accuracy: 0.9734 - val_loss: 0.0118 - val_accuracy: 0.9055
# Epoch 161/200
#  - 20s - loss: 0.0954 - accuracy: 0.9681 - val_loss: 0.3200 - val_accuracy: 0.8811
# Epoch 162/200
#  - 20s - loss: 0.0747 - accuracy: 0.9788 - val_loss: 0.5851 - val_accuracy: 0.8902
# Epoch 163/200
#  - 20s - loss: 0.0798 - accuracy: 0.9689 - val_loss: 0.7154 - val_accuracy: 0.9085
# Epoch 164/200
#  - 19s - loss: 0.0525 - accuracy: 0.9833 - val_loss: 0.2484 - val_accuracy: 0.9024
# Epoch 165/200
#  - 20s - loss: 0.0687 - accuracy: 0.9757 - val_loss: 0.0869 - val_accuracy: 0.8628
# Epoch 166/200
#  - 19s - loss: 0.0706 - accuracy: 0.9704 - val_loss: 0.0980 - val_accuracy: 0.8963
# Epoch 167/200
#  - 20s - loss: 0.0968 - accuracy: 0.9628 - val_loss: 0.0029 - val_accuracy: 0.8841
# Epoch 168/200
#  - 19s - loss: 0.0607 - accuracy: 0.9795 - val_loss: 0.9378 - val_accuracy: 0.8872
# Epoch 169/200
#  - 20s - loss: 0.0703 - accuracy: 0.9742 - val_loss: 0.2151 - val_accuracy: 0.8750
# Epoch 170/200
#  - 19s - loss: 0.0778 - accuracy: 0.9772 - val_loss: 0.0324 - val_accuracy: 0.9024
# Epoch 171/200
#  - 20s - loss: 0.0778 - accuracy: 0.9750 - val_loss: 0.0045 - val_accuracy: 0.9024
# Epoch 172/200
#  - 19s - loss: 0.0649 - accuracy: 0.9780 - val_loss: 0.0011 - val_accuracy: 0.9085
# Epoch 173/200
#  - 20s - loss: 0.1076 - accuracy: 0.9621 - val_loss: 0.0215 - val_accuracy: 0.8841
# Epoch 174/200
#  - 19s - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.8357 - val_accuracy: 0.9085
# Epoch 175/200
#  - 20s - loss: 0.0492 - accuracy: 0.9848 - val_loss: 0.0029 - val_accuracy: 0.9085
# Epoch 176/200
#  - 20s - loss: 0.0546 - accuracy: 0.9795 - val_loss: 0.4945 - val_accuracy: 0.8902
# Epoch 177/200
#  - 20s - loss: 0.0602 - accuracy: 0.9750 - val_loss: 0.1795 - val_accuracy: 0.8994
# Epoch 178/200
#  - 19s - loss: 0.0580 - accuracy: 0.9750 - val_loss: 0.0621 - val_accuracy: 0.9024
# Epoch 179/200
#  - 20s - loss: 0.0578 - accuracy: 0.9833 - val_loss: 0.0363 - val_accuracy: 0.8902
# Epoch 180/200
#  - 19s - loss: 0.0649 - accuracy: 0.9734 - val_loss: 0.0060 - val_accuracy: 0.9116
# Epoch 181/200
#  - 20s - loss: 0.0497 - accuracy: 0.9810 - val_loss: 0.0842 - val_accuracy: 0.8963
# Epoch 182/200
#  - 19s - loss: 0.0366 - accuracy: 0.9856 - val_loss: 0.4274 - val_accuracy: 0.8994
# Epoch 183/200
#  - 20s - loss: 0.1066 - accuracy: 0.9628 - val_loss: 0.0322 - val_accuracy: 0.9055
# Epoch 184/200
#  - 19s - loss: 0.0690 - accuracy: 0.9795 - val_loss: 0.7332 - val_accuracy: 0.9116
# Epoch 185/200
#  - 20s - loss: 0.0649 - accuracy: 0.9757 - val_loss: 0.0484 - val_accuracy: 0.9024
# Epoch 186/200
#  - 20s - loss: 0.0490 - accuracy: 0.9879 - val_loss: 0.6726 - val_accuracy: 0.8933
# Epoch 187/200
#  - 20s - loss: 0.0591 - accuracy: 0.9757 - val_loss: 0.0621 - val_accuracy: 0.9177
# Epoch 188/200
#  - 20s - loss: 0.0533 - accuracy: 0.9841 - val_loss: 0.6042 - val_accuracy: 0.9055
# Epoch 189/200
#  - 19s - loss: 0.0583 - accuracy: 0.9788 - val_loss: 6.6142e-05 - val_accuracy: 0.9085
# Epoch 190/200
#  - 20s - loss: 0.0460 - accuracy: 0.9833 - val_loss: 0.3961 - val_accuracy: 0.9085
# Epoch 191/200
#  - 19s - loss: 0.0558 - accuracy: 0.9803 - val_loss: 0.0011 - val_accuracy: 0.9055
# Epoch 192/200
#  - 20s - loss: 0.0576 - accuracy: 0.9780 - val_loss: 0.8128 - val_accuracy: 0.8872
# Epoch 193/200
#  - 20s - loss: 0.0958 - accuracy: 0.9750 - val_loss: 0.8800 - val_accuracy: 0.8750
# Epoch 194/200
#  - 19s - loss: 0.0929 - accuracy: 0.9666 - val_loss: 0.3150 - val_accuracy: 0.9055
# Epoch 195/200
#  - 19s - loss: 0.0453 - accuracy: 0.9825 - val_loss: 0.0083 - val_accuracy: 0.9024
# Epoch 196/200
#  - 19s - loss: 0.0462 - accuracy: 0.9856 - val_loss: 0.0492 - val_accuracy: 0.9085
# Epoch 197/200
#  - 19s - loss: 0.0435 - accuracy: 0.9848 - val_loss: 1.1511 - val_accuracy: 0.9177
# Epoch 198/200
#  - 19s - loss: 0.1220 - accuracy: 0.9666 - val_loss: 1.4100 - val_accuracy: 0.8902
# Epoch 199/200
#  - 19s - loss: 0.0676 - accuracy: 0.9750 - val_loss: 0.0017 - val_accuracy: 0.8811
# Epoch 200/200
#  - 19s - loss: 0.0463 - accuracy: 0.9818 - val_loss: 0.3167 - val_accuracy: 0.8841

# %%
# make a prediction for test image.

model = load_model('final_model.h5')

# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(224, 224))
	# convert to array
	img = img_to_array(img)
	# reshape into a single sample with 3 channels
	img = img.reshape(1, 224, 224, 3)
	# center pixel data
	img = img.astype('float32')
	return img

# load an image and predict the class
def run_example(pic):
	# load the image
	img = load_image(pic)
 
	# predict the class
	result = model.predict(img)
	return int(result[0])

# %%
def show_test_image(pic):
  img = cv2.imread(pic)
  img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(img_cvt)
  ttl = run_example(pic)
  plt.title(ttl)
  plt.show()

# %%
# entry point, run the example

testdf = pd.read_csv(DATA_DIR+"test.csv")

testdf
# Out:
#     image_names
# 0      1960.jpg
# 1       668.jpg
# 2      2082.jpg
# 3       808.jpg
# 4      1907.jpg
# ..          ...
# 701     674.jpg
# 702    1027.jpg
# 703     447.jpg
# 704    2176.jpg
# 705    1014.jpg
#
# [706 rows x 1 columns]

# %%
# Run all the images in the loop and print for some random samples in test.

df = pd.DataFrame(columns=['image_names','emergency_or_not'])
test_img_name = testdf['image_names'].tolist()
for i,photo in enumerate(test_img_name):
  pred = run_example(TEST_PATH+photo)
  print(i,photo,pred)
  df.loc[i] = [photo,pred]
df
# Out:
# 0 1960.jpg 0
# 1 668.jpg 1
# 2 2082.jpg 0
# 3 808.jpg 1
# 4 1907.jpg 0
# 5 350.jpg 1
# 6 1557.jpg 0
# 7 111.jpg 1
# 8 1952.jpg 0
# 9 1466.jpg 0
# 10 2071.jpg 0
# 11 1891.jpg 0
# 12 1900.jpg 1
# 13 1927.jpg 0
# 14 1414.jpg 0
# 15 134.jpg 1
# 16 1037.jpg 0
# 17 56.jpg 0
# 18 208.jpg 1
# 19 629.jpg 0
# 20 979.jpg 1
# 21 2099.jpg 0
# 22 332.jpg 0
# 23 1814.jpg 0
# 24 1094.jpg 0
# 25 1886.jpg 0
# 26 342.jpg 1
# 27 2134.jpg 0
# 28 1465.jpg 0
# 29 482.jpg 0
# 30 229.jpg 1
# 31 1078.jpg 0
# 32 611.jpg 1
# 33 1349.jpg 0
# 34 1805.jpg 0
# 35 1947.jpg 0
# 36 299.jpg 0
# 37 463.jpg 1
# 38 2154.jpg 0
# 39 1244.jpg 0
# 664 458.jpg 1
# 665 78.jpg 1
# 666 2091.jpg 0
# 667 32.jpg 1
# 668 916.jpg 1
# 669 1644.jpg 0
# 670 2113.jpg 1
# 671 380.jpg 1
# 672 226.jpg 1
# 673 1208.jpg 0
# 674 1321.jpg 0
# 675 305.jpg 0
# 676 209.jpg 1
# 677 1143.jpg 0
# 678 1452.jpg 0
# 679 2331.jpg 0
# 680 1491.jpg 0
# 681 715.jpg 1
# 682 707.jpg 1
# 683 1852.jpg 0
# 684 1000.jpg 0
# 685 2312.jpg 0
# 686 483.jpg 1
# 687 2206.jpg 0
# 688 277.jpg 1
# 689 2338.jpg 0
# 690 221.jpg 0
# 691 1459.jpg 0
# 692 571.jpg 1
# 693 411.jpg 1
# 694 1089.jpg 0
# 695 1103.jpg 0
# 696 585.jpg 1
# 697 1054.jpg 0
# 698 1502.jpg 0
# 699 2345.jpg 0
# 700 1362.jpg 0
# 701 674.jpg 1
# 702 1027.jpg 0
# 703 447.jpg 1
# 704 2176.jpg 0
# 705 1014.jpg 0
#     image_names emergency_or_not
# 0      1960.jpg                0
# 1       668.jpg                1
# 2      2082.jpg                0
# 3       808.jpg                1
# 4      1907.jpg                0
# ..          ...              ...
# 701     674.jpg                1
# 702    1027.jpg                0
# 703     447.jpg                1
# 704    2176.jpg                0
# 705    1014.jpg                0
#
# [706 rows x 2 columns]

# %%
# Lets bundle the predition for submission, Dont forget to increate the file counter to avoid overwriting.
CURRENT_SUBMISSION = 26
df.to_csv("Subimission_"+str(CURRENT_SUBMISSION)+".csv", index=False)

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  4906.034180239999

# %%
1+1

# %% [markdown]
# #  Data Exploration and post mortem analysis

# %%
# Post Mortem analysis for Non Emergency Predictions.
from tqdm import tqdm
from keras.preprocessing import image
from keras.models import load_model

loaded_model = load_model("final_model.h6")
# loaded_model.summary()
# gc.collect()
dir_images = ("/content/sample_data/data/train/0_nonemergency/")
df_train = pd.read_csv("/content/drive/My Drive/ComputerVisionHackathon/train.csv")
df_train = df_train[(df_train["emergency_or_not"] == 0)]
images_name_list = df_train['image_names'].tolist()
train_image = []
#for i in tqdm(range(df_train.shape[0])):
    
for i,item in enumerate(images_name_list):
    #print(i,dir_images + str(item))
      try:
        img = image.load_img(dir_images +str(item), color_mode = "rgb")
      except FileNotFoundError:
        print('File does not exist : ',dir_images +str(item))
      img = image.img_to_array(img)
      img = img/255
      train_image.append(img)
    
    #print(train_image)
X = np.array(train_image)
y_pred = loaded_model.predict_classes(X)
df_train['prediction'] = y_pred
df_train_accuracy = df_train.groupby(['emergency_or_not', 'prediction']).size().reset_index(name='num_images')
df_train_accuracy['perc_images'] = 100*df_train_accuracy['num_images']/df_train_accuracy['num_images'].sum()
df_train_accuracy.head()
df_issues = df_train[(df_train['prediction'] != df_train['emergency_or_not'])]
# df_issues.head()
#os.chdir(dir_base)
df_issues.to_csv('df_issues_nonemer.csv', header=True, index=False)
df_issues

# %%
# Post Mortem analysis for Emergency Predictions.

dir_images = ("/content/sample_data/data/train/1_emergency/")
df_train = pd.read_csv("/content/drive/My Drive/ComputerVisionHackathon/train.csv")
df_train = df_train[(df_train["emergency_or_not"] == 1)]
images_name_list = df_train['image_names'].tolist()
train_image = []
#for i in tqdm(range(df_train.shape[0])):
    
for i,item in enumerate(images_name_list):
    print(i,dir_images + str(item))
    try:
      img = image.load_img(dir_images +str(item), color_mode = "rgb")
    except FileNotFoundError:
      img = image.img_to_array(img)
    img = img/255
    train_image.append(img)
    #print(train_image)
X = np.array(train_image)
y_pred = loaded_model.predict_classes(X)
df_train['prediction'] = y_pred
df_train_accuracy = df_train.groupby(['emergency_or_not', 'prediction']).size().reset_index(name='num_images')
df_train_accuracy['perc_images'] = 100*df_train_accuracy['num_images']/df_train_accuracy['num_images'].sum()
df_train_accuracy.head()
df_issues = df_train[(df_train['prediction'] != df_train['emergency_or_not'])]
# df_issues.head()
#os.chdir(dir_base)
df_issues.to_csv('df_issues_emer.csv', header=True, index=False)
df_issues

# %% [markdown]
# # **These are the pre processing to find duplicate images**

# %%
import hashlib
#from scipy.misc import imread, imresize, imshow
from cv2 import imread
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os
def file_hash(filename):
    with open(filename,'rb') as f:
        return md5(f.read()).hexdigest()

os.getcwd()
#os.chdir('/content/drive/My Drive/ComputerVisionHackathon/images')
os.chdir('/content/sample_data/uniqueimages/')
os.getcwd()

files_list = os.listdir('.')
print (len(files_list))

duplicates=[]
hash_keys=dict()
image_dict=dict()
for index, filename in enumerate(os.listdir('.')):
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys:
            hash_keys[filehash]=[]
            hash_keys[filehash].append(filename)
        else:
            duplicates.append((index,hash_keys[filehash]))
            hash_keys[filehash].append(filename)

#print(duplicates)
print(hash_keys)

# %%
# Data Exploration to identify duplicates and if prediction was class is different for duplicates.
import sys
df_train = pd.read_csv(DATA_DIR+"train.csv")
df_train.head()
for i in hash_keys:
  if len(hash_keys[i]) > 1:
    print("")
    print(hash_keys[i])
    emerOrNot=100
    for img in hash_keys[i]:
       new_emerOrNot = df_train.loc[df_train['image_names']==img,"emergency_or_not"].iloc[0]
       if emerOrNot == 100:
         emerOrNot = new_emerOrNot
       elif emerOrNot != new_emerOrNot:
         print("-------------- C O N F L I C T --------------")
       sys.stdout.write(str(df_train.loc[df_train['image_names']==img,"emergency_or_not"].iloc[0]))
       sys.stdout.write('_')
       sys.stdout.write(img)
       sys.stdout.write(" - ")
       #print(df_train.loc[df_train['image_names']==img,"emergency_or_not"].iloc[0])

# %%
df_train = pd.read_csv("/content/drive/My Drive/ComputerVisionHackathon/train.csv")
image_to_delete = []
for i in hash_keys:
  just_for_print_del=[]
  noofitems = len(hash_keys[i])
  if noofitems > 1:
    fig=plt.figure(figsize=(10, 10))
    columns = noofitems
    count=1
    emerOrNot=100
    for img in hash_keys[i]:


      new_emerOrNot = df_train.loc[df_train['image_names']==img,"emergency_or_not"].iloc[0]
      if emerOrNot == 100:
        emerOrNot = new_emerOrNot
      elif emerOrNot != new_emerOrNot:
        print(emerOrNot,"-------------- C O N F L I C T --------------",new_emerOrNot)
        image_to_delete.append(img)
        just_for_print_del.append(img)
      else:
        image_to_delete.append(img)
        just_for_print_del.append(img)
      #sys.stdout.write(str(df_train.loc[df_train['image_names']==img,"emergency_or_not"].iloc[0]))
      #sys.stdout.write('_')
      #sys.stdout.write(img)
      #sys.stdout.write(" - ")
      img_title = str(new_emerOrNot)+'_'+str(img)
      try:
        fig.add_subplot(1, columns, count)
        plt.title(img_title)
        plt.imshow(imread(img))
      except OSError as e:
        continue
      count=count+1
    plt.show()
    print(just_for_print_del)
print(image_to_delete)

# %%
#Replacing 54.jpg with 2029. as it is correctly categorised as an emergency vehicle
for index,item in enumerate(image_to_delete):
  if item == "54.jpg":
    position_to_replace=index
    print(index,item)
image_to_delete[position_to_replace]='2029.jpg'
print(image_to_delete[position_to_replace])

# %%
# !ls /content/sample_data/uniqueimages/ | wc -l
os.getcwd()
#os.chdir('/content/drive/My Drive/ComputerVisionHackathon/images')
os.chdir('/content/sample_data/uniqueimages/')
os.getcwd()

for index in image_to_delete:
    os.remove(index)
# !ls /content/sample_data/uniqueimages/ | wc -l

# %%
len(image_to_delete)

# %%
df_train = pd.read_csv("/content/drive/My Drive/ComputerVisionHackathon/train.csv")
df_train.head()

df_train = df_train[(df_train["emergency_or_not"] == 1)]
emeregency_list = df_train['image_names'].tolist()

for item in emeregency_list:
  if item in image_to_delete:
    continue
  else:
    item_to_move='/content/sample_data/uniqueimages/'+str(item)
    print(item_to_move)
    # !cp $item_to_move /content/sample_data/data/train/1_emergency/

# %%
df_train = pd.read_csv("/content/drive/My Drive/ComputerVisionHackathon/train.csv")
df_train.head()

df_train = df_train[(df_train["emergency_or_not"] == 0)]
non_emeregency_list = df_train['image_names'].tolist()

for count,item in enumerate(non_emeregency_list):
  if item in image_to_delete:
    print(count,'----ESCAPE-----',item_to_move)
    continue
  else:
    item_to_move='/content/sample_data/uniqueimages/'+str(item)
    print(count,item_to_move)
    # !cp $item_to_move /content/sample_data/data/train/0_nonemergency/

# %%
import pandas as pd

df = pd.read_csv("/content/epoch_trends.csv")
df_loss = df[["val_loss","loss"]]
df_loss1 = df_loss1[-50:]
df_loss1.plot();

df_accuracy = df[["val_accuracy","accuracy"]]
df_accuracy1 = df_accuracy[-50:]
df_accuracy1.plot();

# %%
df_loss = df[["val_loss","loss"]]
df_loss1 = df_loss[-100:]
df_loss1 = df_loss1.head(50)
df_loss1.plot();

df_accuracy = df[{"val_accuracy","accuracy"}]
df_accuracy1 = df_accuracy[-100:]
df_accuracy1 = df_accuracy1.head(50)
df_accuracy1.plot();

# %%
import pandas as pd
import matplotlib.pyplot as plt
from cv2 import imread

df = pd.read_csv("/content/sample_data/Subimission_15.csv")
TEST_PATH='/content/sample_data/test/'

emergency_cases = df[(df["emergency_or_not"] == 1)]
emergency_cases = emergency_cases['image_names'].tolist()
count=1
fig=plt.figure(figsize=(12, 12))
for pic in emergency_cases:
  
  try:
    fig.add_subplot(1, 2, count)
    plt.title(pic)
    plt.imshow(imread(TEST_PATH+str(pic)))
  except OSError as e:
    print(pic)
    continue
  if count == 2:
    count = 1
    plt.show()
    fig=plt.figure(figsize=(12, 12))
  else:
    count= count+1
